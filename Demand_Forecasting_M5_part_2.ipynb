# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sales_28.csv')
cal = pd.read_csv('cal.csv')

# %%
df.head(3)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  m_1  m_2  m_3  m_4  ...  m_60  m_61  m_62  m_63  m_64  m_65  m_66  \
# 0       CA    0    0    0    0  ...    22    18    16    12    21    26    19
# 1       CA    0    0    0    0  ...    15     9     9    11    27     4     4
# 2       CA    0    0    0    0  ...     9    21    13    20    42    13     9
#
#    m_67  m_68  m_69
# 0    30    28    33
# 1     7     5     3
# 2    14     9    22
#
# [3 rows x 75 columns]

# %%
cal.head(3)
# Out:
#    wm_yr_wk  wday  month  year    d  event  day
# 0         1     1      1  2011  d_1      0   29
# 1         1     2      1  2011  d_2      0   30
# 2         1     3      1  2011  d_3      0   31

# %%
#columns id and store_id are redundant, do let's drop it
df = df.drop(columns=['id','store_id'])

# %%
df.head(3)
# Out:
#          item_id    dept_id   cat_id state_id  m_1  m_2  m_3  m_4  m_5  m_6  \
# 0  HOBBIES_1_001  HOBBIES_1  HOBBIES       CA    0    0    0    0    0    0
# 1  HOBBIES_1_002  HOBBIES_1  HOBBIES       CA    0    0    0    0    0    7
# 2  HOBBIES_1_003  HOBBIES_1  HOBBIES       CA    0    0    0    0    0    0
#
#    ...  m_60  m_61  m_62  m_63  m_64  m_65  m_66  m_67  m_68  m_69
# 0  ...    22    18    16    12    21    26    19    30    28    33
# 1  ...    15     9     9    11    27     4     4     7     5     3
# 2  ...     9    21    13    20    42    13     9    14     9    22
#
# [3 rows x 73 columns]

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['item_id',
#  'dept_id',
#  'cat_id',
#  'state_id',
#  'm_1',
#  'm_2',
#  'm_3',
#  'm_4',
#  'm_5',
#  'm_6',
#  'm_7',
#  'm_8',
#  'm_9',
#  'm_10',
#  'm_11',
#  'm_12',
#  'm_13',
#  'm_14',
#  'm_15',
#  'm_16',
#  'm_17',
#  'm_18',
#  'm_19',
#  'm_20',
#  'm_21',
#  'm_22',
#  'm_23',
#  'm_24',
#  'm_25',
#  'm_26',
#  'm_27',
#  'm_28',
#  'm_29',
#  'm_30',
#  'm_31',
#  'm_32',
#  'm_33',
#  'm_34',
#  'm_35',
#  'm_36',
#  'm_37',
#  'm_38',
#  'm_39',
#  'm_40',
#  'm_41',
#  'm_42',
#  'm_43',
#  'm_44',
#  'm_45',
#  'm_46',
#  'm_47',
#  'm_48',
#  'm_49',
#  'm_50',
#  'm_51',
#  'm_52',
#  'm_53',
#  'm_54',
#  'm_55',
#  'm_56',
#  'm_57',
#  'm_58',
#  'm_59',
#  'm_60',
#  'm_61',
#  'm_62',
#  'm_63',
#  'm_64',
#  'm_65',
#  'm_66',
#  'm_67',
#  'm_68',
#  'm_69']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   30490 non-null  object
#  1   dept_id   30490 non-null  object
#  2   cat_id    30490 non-null  object
#  3   state_id  30490 non-null  object
#  4   m_1       30490 non-null  int64
#  5   m_2       30490 non-null  int64
#  6   m_3       30490 non-null  int64
#  7   m_4       30490 non-null  int64
#  8   m_5       30490 non-null  int64
#  9   m_6       30490 non-null  int64
#  10  m_7       30490 non-null  int64
#  11  m_8       30490 non-null  int64
#  12  m_9       30490 non-null  int64
#  13  m_10      30490 non-null  int64
#  14  m_11      30490 non-null  int64
#  15  m_12      30490 non-null  int64
#  16  m_13      30490 non-null  int64
#  17  m_14      30490 non-null  int64
#  18  m_15      30490 non-null  int64
#  19  m_16      30490 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 m_1           m_2           m_3           m_4           m_5  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean      24.095867     23.031683     22.967498     21.370253     22.702165
# std       84.937565     76.956197     77.966476     73.691488     79.860274
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%       18.000000     17.000000     18.000000     17.000000     18.000000
# max     3930.000000   2816.000000   2844.000000   2814.000000   3060.000000
#
#                 m_6           m_7           m_8           m_9          m_10  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean      23.651296     23.957822     24.637619     25.557461     25.927484
# ...

# %%
df.isnull().sum()
# Out:
# item_id     0
# dept_id     0
# cat_id      0
# state_id    0
# m_1         0
#            ..
# m_65        0
# m_66        0
# m_67        0
# m_68        0
# m_69        0
# Length: 73, dtype: int64

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
df.describe(include=['object'])
# Out:
#               item_id  dept_id cat_id state_id
# count           30490    30490  30490    30490
# unique           3049        7      3        3
# top     HOBBIES_1_001  FOODS_3  FOODS       CA
# freq               10     8230  14370    12196

# %%
filtered_df = df[df['item_id'] == 'HOBBIES_1_001']
filtered_df.head()
# Out:
#              item_id    dept_id   cat_id state_id  m_1  m_2  m_3  m_4  m_5  \
# 0      HOBBIES_1_001  HOBBIES_1  HOBBIES       CA    0    0    0    0    0
# 3049   HOBBIES_1_001  HOBBIES_1  HOBBIES       CA    0    0    0    0    0
# 6098   HOBBIES_1_001  HOBBIES_1  HOBBIES       CA    0    0    0    0    0
# 9147   HOBBIES_1_001  HOBBIES_1  HOBBIES       CA    0    0    0    0    0
# 12196  HOBBIES_1_001  HOBBIES_1  HOBBIES       TX    0    0    0    0    0
#
#        m_6  ...  m_60  m_61  m_62  m_63  m_64  m_65  m_66  m_67  m_68  m_69
# 0        0  ...    22    18    16    12    21    26    19    30    28    33
# 3049     0  ...    18    22    16    21    17    14    19    21    19    23
# 6098     0  ...    18    11    23    27    24    20    22    27    30    34
# 9147     0  ...    11    19    25    22    22    26    21    24    23    21
# 12196    0  ...     5     7     8     5     6     4     6    11     9    10
#
# [5 rows x 73 columns]

# %%
#dropping dept_id as dept_id = cat_id + sub_category_id
df = df.drop(columns=['dept_id'])

# %%
df.head()
# Out:
#          item_id   cat_id state_id  m_1  m_2  m_3  m_4  m_5  m_6  m_7  ...  \
# 0  HOBBIES_1_001  HOBBIES       CA    0    0    0    0    0    0    0  ...
# 1  HOBBIES_1_002  HOBBIES       CA    0    0    0    0    0    7    3  ...
# 2  HOBBIES_1_003  HOBBIES       CA    0    0    0    0    0    0    0  ...
# 3  HOBBIES_1_004  HOBBIES       CA    0   10   21   33   25   45   44  ...
# 4  HOBBIES_1_005  HOBBIES       CA    0    0    0    0   50   14   16  ...
#
#    m_60  m_61  m_62  m_63  m_64  m_65  m_66  m_67  m_68  m_69
# 0    22    18    16    12    21    26    19    30    28    33
# 1    15     9     9    11    27     4     4     7     5     3
# 2     9    21    13    20    42    13     9    14     9    22
# 3    52    50    58    46    45    49    64    49    56    55
# 4    39    38    38    36    45    15    32    30    34    47
#
# [5 rows x 72 columns]

# %%
#adding records where item_id, cat_id and state_id are the same
aggregated_df = df.groupby(['item_id', 'cat_id', 'state_id'], as_index=False).sum()
aggregated_df.head()
# Out:
#        item_id cat_id state_id  m_1  m_2  m_3  m_4  m_5  m_6  m_7  ...  m_60  \
# 0  FOODS_1_001  FOODS       CA  154  141  113  164  174  132  108  ...    67
# 1  FOODS_1_001  FOODS       TX   54   53   65   64   66   54   25  ...    48
# 2  FOODS_1_001  FOODS       WI   82   86   85   85   72   75   39  ...    29
# 3  FOODS_1_002  FOODS       CA   54   56   57   46   46   47   47  ...    46
# 4  FOODS_1_002  FOODS       TX   12   25   17   21   29   23   30  ...    19
#
#    m_61  m_62  m_63  m_64  m_65  m_66  m_67  m_68  m_69
# 0    96    93    81    98    78    85    86    87   103
# 1    36    39    44    48    68    44    39    34    34
# 2    28    24    27    25    15    29    19    31    39
# 3    40    33    30    46    28    44    57    49    59
# 4    17    24    12    11    11    14    13    18    22
#
# [5 rows x 72 columns]

# %%
aggregated_df.shape
# Out:
# (9147, 72)

# %%
#statewise sales trends
m_columns = [f'm_{i}' for i in range(1, 70)]
state_demand = aggregated_df.groupby('state_id')[m_columns].sum()

# %%
state_demand.head()
# Out:
#              m_1     m_2     m_3     m_4     m_5     m_6     m_7     m_8  \
# state_id
# CA        320870  310057  315381  290127  304619  321208  321796  331737
# TX        213634  208246  207807  199335  216161  225482  230164  241424
# WI        200179  183933  177091  162117  171409  174438  178514  178040
#
#              m_9    m_10  ...    m_60    m_61    m_62    m_63    m_64    m_65  \
# state_id                  ...
# CA        346895  357506  ...  500976  499628  496141  455670  433181  455752
# TX        246136  241523  ...  300273  300448  301897  285755  274451  286720
# WI        186216  191500  ...  306706  317456  325603  311284  309816  322629
#
#             m_66    m_67    m_68    m_69
# state_id
# CA        487961  494099  500576  510590
# TX        310600  314630  312229  318174
# WI        360709  365255  367004  370446
#
# [3 rows x 69 columns]

# %%
months = list(range(1, 70))
state_demand.reset_index(inplace=True)
for state in state_demand['state_id']:
  plt.plot(months, state_demand[state_demand['state_id'] == state].iloc[0, 1:], label=state)
plt.xlabel('Month')
plt.ylabel('Total Demand')
plt.title('State-wise Demand Trends Over Time')
plt.legend(title='State')
plt.show()

# %%
#category_wise sales trends
cat_demand = aggregated_df.groupby('cat_id')[m_columns].sum()
cat_demand.reset_index(inplace=True)
for cat in cat_demand['cat_id']:
  plt.plot(months, cat_demand[cat_demand['cat_id'] == cat].iloc[0, 1:], label=cat)
plt.xlabel('Month')
plt.ylabel('Total Demand')
plt.title('Category-wise Demand Trends Over Time')
plt.legend(title='Category')
plt.show()

# %%
#for a particular item
for i in range(3):
  sales_data = aggregated_df.iloc[i, 3:].values
  plt.plot(months, sales_data, marker='o')
  plt.title('Demand Over Time for Items')
  plt.xlabel('Month')
  plt.ylabel('Sales')
  plt.grid()
plt.show()

# %%
#total sales in terms of categories
category_sales = aggregated_df.groupby('cat_id').sum().iloc[:, 3:].sum(axis=1)
category_sales.plot(kind='bar', title='Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
#Sales by category for month 1
month_cat_sales = df[['cat_id'] + list(aggregated_df.columns[3:])].groupby('cat_id').sum().iloc[:, 0]  # For m_1
month_cat_sales.plot(kind='pie', autopct='%1.1f%%', title='Market Share for Month 1')
plt.show()

# %%
#total sales in terms of state
state_sales = aggregated_df.groupby('state_id').sum().iloc[:, 3:].sum(axis=1)
state_sales.plot(kind='bar', title='Total Sales by State')
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.show()

# %%
#Sales by state for month 1
month_state_sales = df[['state_id'] + list(aggregated_df.columns[3:])].groupby('state_id').sum().iloc[:, 0]  # For m_1
month_state_sales.plot(kind='pie', autopct='%1.1f%%', title='Market Share for Month 1')
plt.show()

# %%
#correlation between sales across months
corr_matrix = aggregated_df[m_columns].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Sales Over Time')
plt.show()

# %%
corr_matrix
# Out:
#            m_1       m_2       m_3       m_4       m_5       m_6       m_7  \
# m_1   1.000000  0.859762  0.834700  0.799101  0.774357  0.751490  0.764751
# m_2   0.859762  1.000000  0.970833  0.913088  0.887305  0.861933  0.875598
# m_3   0.834700  0.970833  1.000000  0.944834  0.909938  0.885908  0.894445
# m_4   0.799101  0.913088  0.944834  1.000000  0.966632  0.941008  0.937576
# m_5   0.774357  0.887305  0.909938  0.966632  1.000000  0.974558  0.964524
# ...        ...       ...       ...       ...       ...       ...       ...
# m_65  0.581671  0.598144  0.598921  0.582768  0.564650  0.564750  0.583698
# m_66  0.628183  0.587094  0.583773  0.567945  0.555278  0.554435  0.572044
# m_67  0.671234  0.601379  0.594325  0.579302  0.573405  0.569958  0.588716
# m_68  0.654067  0.582244  0.573471  0.552725  0.542700  0.535730  0.561017
# m_69  0.652938  0.577705  0.567434  0.548494  0.535649  0.529964  0.560242
#
# ...

# %%
df_cat_encoded = pd.get_dummies(df['cat_id'], prefix='cat')
df_with_encoded_cat = pd.concat([df[m_columns], df_cat_encoded], axis=1)
corr_matrix_cat = df_with_encoded_cat.corr()
print(corr_matrix_cat[['cat_FOODS', 'cat_HOUSEHOLD', 'cat_HOBBIES']])
# Out:
#                cat_FOODS  cat_HOUSEHOLD  cat_HOBBIES
# m_1             0.140380      -0.101259    -0.056602
# m_2             0.139808      -0.096467    -0.061723
# m_3             0.132284      -0.096004    -0.052623
# m_4             0.121589      -0.089800    -0.046464
# m_5             0.127931      -0.090987    -0.053161
# ...                  ...            ...          ...
# m_68            0.182661      -0.102295    -0.109656
# m_69            0.189357      -0.110059    -0.108770
# cat_FOODS       1.000000      -0.682790    -0.450292
# cat_HOBBIES    -0.450292      -0.344897     1.000000
# cat_HOUSEHOLD  -0.682790       1.000000    -0.344897
#
# [72 rows x 3 columns]

# %%
df_state_encoded = pd.get_dummies(df['state_id'], prefix='state')
df_with_encoded_state = pd.concat([df[m_columns], df_state_encoded], axis=1)
corr_matrix_state = df_with_encoded_state.corr()
print(corr_matrix_state[['state_CA', 'state_TX', 'state_WI']])
# Out:
#           state_CA  state_TX  state_WI
# m_1       0.021279 -0.005705 -0.017043
# m_2       0.025370 -0.002255 -0.024867
# m_3       0.030285 -0.002090 -0.030287
# m_4       0.026797  0.003750 -0.032397
# m_5       0.023258  0.007622 -0.032486
# ...            ...       ...       ...
# m_68      0.022561 -0.035114  0.010995
# m_69      0.024582 -0.035363  0.009084
# state_CA  1.000000 -0.534522 -0.534522
# state_TX -0.534522  1.000000 -0.428571
# state_WI -0.534522 -0.428571  1.000000
#
# [72 rows x 3 columns]

# %%
grouped_by_cat = df.groupby('cat_id')[m_columns].mean()
corr_by_cat = grouped_by_cat.corr()
print(corr_by_cat)
grouped_by_state = df.groupby('state_id')[m_columns].mean()
corr_by_state = grouped_by_state.corr()
print(corr_by_state)
# Out:
#            m_1       m_2       m_3       m_4       m_5       m_6       m_7  \
# m_1   1.000000  0.998539  0.999970  0.999549  0.999847  0.999820  0.999240
# m_2   0.998539  1.000000  0.998095  0.996467  0.999332  0.999384  0.999886
# m_3   0.999970  0.998095  1.000000  0.999751  0.999683  0.999645  0.998912
# m_4   0.999549  0.996467  0.999751  1.000000  0.998871  0.998801  0.997620
# m_5   0.999847  0.999332  0.999683  0.998871  1.000000  0.999999  0.999770
# ...        ...       ...       ...       ...       ...       ...       ...
# m_65  0.969874  0.981620  0.967973  0.962124  0.973990  0.974317  0.978630
# m_66  0.963364  0.976448  0.961274  0.954879  0.967912  0.968275  0.973083
# m_67  0.957015  0.971289  0.954758  0.947878  0.961947  0.962341  0.967590
# m_68  0.964892  0.977674  0.962846  0.956573  0.969343  0.969698  0.974394
# m_69  0.972977  0.984032  0.971174  0.965607  0.976871  0.977179  0.981235
#
# ...
